# %% [markdown]
# <a href="https://colab.research.google.com/github/saikiraanDS/ML_Live_Class/blob/main/linearRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
ROOT = "/content/drive/MyDrive/Day 1 Machine learning"

# %%
import os
os.chdir(ROOT)

# %%
# !ls
# Out:
# linearRegression.ipynb	test.txt

# %%
assert ROOT == os.getcwd()

# %%
os.getcwd()
# Out:
# '/content/drive/MyDrive/Day 1 Machine learning'

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/advertising.csv")

# %%
df
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]

# %%
df["total_spent"] = df['TV'] + df['Radio'] + df['Newspaper']

# %%
df.head()
# Out:
#       TV  Radio  Newspaper  Sales  total_spent
# 0  230.1   37.8       69.2   22.1        337.1
# 1   44.5   39.3       45.1   10.4        128.9
# 2   17.2   45.9       69.3   12.0        132.4
# 3  151.5   41.3       58.5   16.5        251.3
# 4  180.8   10.8       58.4   17.9        250.0

# %%
sns.scatterplot(data = df, x = 'total_spent', y='Sales')

# %%
sns.regplot(data =df, x="total_spent", y ='Sales', color = 'red')

# %%
x =df['total_spent']
y = df['Sales']

# %%
# help(sns.regplot)

# %%
np.polyfit(x,y, deg=1)
# Out:
# array([0.0525585, 4.573573 ])

# %%
potential_spend = np.linspace(0,500,100) # x
potential_spend
# Out:
# array([  0.        ,   5.05050505,  10.1010101 ,  15.15151515,
#         20.2020202 ,  25.25252525,  30.3030303 ,  35.35353535,
#         40.4040404 ,  45.45454545,  50.50505051,  55.55555556,
#         60.60606061,  65.65656566,  70.70707071,  75.75757576,
#         80.80808081,  85.85858586,  90.90909091,  95.95959596,
#        101.01010101, 106.06060606, 111.11111111, 116.16161616,
#        121.21212121, 126.26262626, 131.31313131, 136.36363636,
#        141.41414141, 146.46464646, 151.51515152, 156.56565657,
#        161.61616162, 166.66666667, 171.71717172, 176.76767677,
#        181.81818182, 186.86868687, 191.91919192, 196.96969697,
#        202.02020202, 207.07070707, 212.12121212, 217.17171717,
#        222.22222222, 227.27272727, 232.32323232, 237.37373737,
#        242.42424242, 247.47474747, 252.52525253, 257.57575758,
#        262.62626263, 267.67676768, 272.72727273, 277.77777778,
#        282.82828283, 287.87878788, 292.92929293, 297.97979798,
# ...

# %%
# y = m*x + b
predicted_sales = 0.0525585 * potential_spend + 4.573573

# %%
predicted_sales
# Out:
# array([ 4.573573  ,  4.83901997,  5.10446694,  5.36991391,  5.63536088,
#         5.90080785,  6.16625482,  6.43170179,  6.69714876,  6.96259573,
#         7.2280427 ,  7.49348967,  7.75893664,  8.02438361,  8.28983058,
#         8.55527755,  8.82072452,  9.08617148,  9.35161845,  9.61706542,
#         9.88251239, 10.14795936, 10.41340633, 10.6788533 , 10.94430027,
#        11.20974724, 11.47519421, 11.74064118, 12.00608815, 12.27153512,
#        12.53698209, 12.80242906, 13.06787603, 13.333323  , 13.59876997,
#        13.86421694, 14.12966391, 14.39511088, 14.66055785, 14.92600482,
#        15.19145179, 15.45689876, 15.72234573, 15.9877927 , 16.25323967,
#        16.51868664, 16.78413361, 17.04958058, 17.31502755, 17.58047452,
#        17.84592148, 18.11136845, 18.37681542, 18.64226239, 18.90770936,
#        19.17315633, 19.4386033 , 19.70405027, 19.96949724, 20.23494421,
#        20.50039118, 20.76583815, 21.03128512, 21.29673209, 21.56217906,
# ...

# %%
sns.scatterplot(x = 'total_spent', y ='Sales', data = df) # scatter plot
plt.plot(potential_spend, predicted_sales, color = 'green') # line

# %%
spend = 200
predicted_sales =0.0525585 * spend + 4.573573

# %%
predicted_sales
# Out:
# 15.085272999999999

# %%
np.polyfit(x,y, deg = 3)
# Out:
# array([ 4.49497819e-08, -7.06143726e-05,  7.48845278e-02,  2.94654345e+00])

# %%
pot_spend = np.linspace(0, 500, 100)

pred_sales = 4.49497819e-08 * pot_spend**3 + -7.06143726e-05*pot_spend**2 +  7.48845278e-02 * pot_spend + 2.94654345e+00

# %%
pred_sales
# Out:
# array([ 2.94654345,  3.32295272,  3.69579433,  4.06510303,  4.43091355,
#         4.79326064,  5.15217904,  5.50770351,  5.85986877,  6.20870959,
#         6.5542607 ,  6.89655684,  7.23563276,  7.57152321,  7.90426293,
#         8.23388666,  8.56042915,  8.88392514,  9.20440938,  9.5219166 ,
#         9.83648156, 10.14813901, 10.45692367, 10.7628703 , 11.06601365,
#        11.36638844, 11.66402944, 11.95897139, 12.25124902, 12.54089709,
#        12.82795033, 13.1124435 , 13.39441133, 13.67388858, 13.95090997,
#        14.22551027, 14.49772421, 14.76758653, 15.03513199, 15.30039533,
#        15.56341128, 15.8242146 , 16.08284003, 16.33932231, 16.59369619,
#        16.84599641, 17.09625771, 17.34451485, 17.59080256, 17.83515559,
#        18.07760868, 18.31819658, 18.55695403, 18.79391578, 19.02911656,
#        19.26259114, 19.49437424, 19.72450061, 19.953005  , 20.17992215,
#        20.40528681, 20.62913372, 20.85149762, 21.07241326, 21.29191538,
# ...

# %%
sns.scatterplot(x ='total_spent', y = 'Sales', data = df)
plt.plot(pot_spend, pred_sales, color ='green') # line

# %%
sns.pairplot(df)

# %%
x = df.drop(['Sales','total_spent'], axis = 1)

# %%
x
# Out:
#         TV  Radio  Newspaper
# 0    230.1   37.8       69.2
# 1     44.5   39.3       45.1
# 2     17.2   45.9       69.3
# 3    151.5   41.3       58.5
# 4    180.8   10.8       58.4
# ..     ...    ...        ...
# 195   38.2    3.7       13.8
# 196   94.2    4.9        8.1
# 197  177.0    9.3        6.4
# 198  283.6   42.0       66.2
# 199  232.1    8.6        8.7
#
# [200 rows x 3 columns]

# %%
y = df['Sales']

# %%
y
# Out:
# 0      22.1
# 1      10.4
# 2      12.0
# 3      16.5
# 4      17.9
#        ...
# 195     7.6
# 196    14.0
# 197    14.8
# 198    25.5
# 199    18.4
# Name: Sales, Length: 200, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.33, random_state = 101)

X_train.head
# Out:
# <bound method NDFrame.head of         TV  Radio  Newspaper
# 154  187.8   21.1        9.5
# 114   78.2   46.8       34.5
# 118  125.7   36.9       79.2
# 64   131.1   42.8       28.9
# 165  234.5    3.4       84.8
# ..     ...    ...        ...
# 63   102.7   29.6        8.4
# 70   199.1   30.6       38.7
# 81   239.8    4.1       36.9
# 11   214.7   24.0        4.0
# 95   163.3   31.6       52.9
#
# [134 rows x 3 columns]>

# %%
len(df)
# Out:
# 200

# %%
len(X_train)
# Out:
# 134

# %%
len(X_test)
# Out:
# 66

# %%
from sklearn.linear_model import LinearRegression
help(LinearRegression)

# %%
model = LinearRegression()

# %%
model.fit(X_train, y_train )
# Out:
# LinearRegression()

# %%
test_pred = model.predict(X_test)
test_pred
# Out:
# array([13.84736062, 21.6208545 , 12.4506434 , 15.53800991,  9.13572388,
#         7.32848067, 22.13382615, 18.99389515, 12.5074889 , 20.10480143,
#        11.14471789, 16.00799576, 17.13131444, 20.51391413, 18.52689489,
#         9.81871779, 19.29995509, 10.02472134,  8.55196221, 21.07099084,
#         7.84483773, 18.13469703, 24.90087497, 23.23638138,  9.50153866,
#        15.6580894 , 23.83636942,  8.88965111, 14.71191831, 10.08773315,
#         9.28121309, 20.03204425, 12.50942245,  6.7209499 , 17.73745681,
#         9.90528961, 10.54065531, 10.3248605 ,  9.01341274, 13.48442892,
#        11.40463282, 12.32027425, 11.24446527,  7.66448064, 11.63858892,
#        10.59311539,  8.22759878, 18.42554295, 15.2491901 , 20.20019412,
#        11.07711531, 16.71290321, 20.96270351, 12.69856152, 15.72864026,
#         6.15801816, 24.13296025, 11.37314587, 21.46171542, 16.49013139,
#        16.70390396, 24.54896417,  9.00346399, 19.27803416, 16.88593651,
#        21.81240684])

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
sns.histplot(data = df, x ='Sales', bins=20)  # distribution of sales

# %%
mean_absolute_error(y_test, test_pred)
# Out:
# 1.4217227776233652

# %%
mean_squared_error(y_test, test_pred)
# Out:
# 3.0821373099675733

# %%
np.sqrt(mean_squared_error(y_test, test_pred))
# Out:
# 1.7556016945672994
